# %%
import pandas as pd
df = pd.read_csv('https://www.dropbox.com/s/2lkpnyjp7mqskg7/Auto.csv?dl=1')
df = df.groupby(['company'],as_index=False).agg({"price":"sum"})
df = df[df["price"]>40000]
y = df.price
x = df.company
from matplotlib import pyplot as plt
plt.bar(x,y)
plt.show()
